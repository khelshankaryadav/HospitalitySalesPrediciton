# %%
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
DataSet = pd.read_csv('Dataset.csv')
DataSet.head()
# Out:
#    Sr        Date  Room Amount  Dine In Amount  Takeaway Amount
# 0   1  01-09-2013          0.0           53722                0
# 1   2  02-09-2013          0.0           39137                0
# 2   3  03-09-2013          0.0             597                0
# 3   4  04-09-2013          0.0               0                0
# 4   5  05-09-2013          0.0            4999                0

# %%
Dine_Temp = DataSet
Dine_Temp.rename(columns={'Date': 'ds'}, inplace=True)
Dine_Temp.rename(columns={'Takeaway Amount': 'y'}, inplace=True)
Dine_Temp.head()
# Out:
#    Sr          ds  Room Amount  Dine In Amount  y
# 0   1  01-09-2013          0.0           53722  0
# 1   2  02-09-2013          0.0           39137  0
# 2   3  03-09-2013          0.0             597  0
# 3   4  04-09-2013          0.0               0  0
# 4   5  05-09-2013          0.0            4999  0

# %%
Data_Dine = Dine_Temp[['ds', 'y']]
Data_Dine.head()
# Out:
#            ds  y
# 0  01-09-2013  0
# 1  02-09-2013  0
# 2  03-09-2013  0
# 3  04-09-2013  0
# 4  05-09-2013  0

# %%
Dine_m = Prophet()
Dine_m.fit(Data_Dine)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
Dine_future = Dine_m.make_future_dataframe(periods=365)
Dine_future.tail()
# Out:
#              ds
# 3362 2022-12-07
# 3363 2022-12-08
# 3364 2022-12-09
# 3365 2022-12-10
# 3366 2022-12-11

# %%
Dine_forecast = Dine_m.predict(Dine_future)
Dine_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds         yhat    yhat_lower    yhat_upper
# 3362 2022-12-07    28.879259 -13098.561110  13744.541536
# 3363 2022-12-08  -306.681260 -13372.614711  13258.867859
# 3364 2022-12-09   271.956736 -12487.036891  13747.952309
# 3365 2022-12-10   -23.239940 -14215.273489  13937.170192
# 3366 2022-12-11  1202.646771 -13250.598476  15284.793700

# %%
plot_plotly(Dine_m, Dine_forecast)

# %%
plot_components_plotly(Dine_m, Dine_forecast)
