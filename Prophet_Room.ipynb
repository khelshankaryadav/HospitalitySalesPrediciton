# %%
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
DataSet = pd.read_csv('Dataset.csv')
DataSet.head()
# Out:
#    Sr        Date  Room Amount  Dine In Amount  Takeaway Amount
# 0   1  01-09-2013          0.0           53722                0
# 1   2  02-09-2013          0.0           39137                0
# 2   3  03-09-2013          0.0             597                0
# 3   4  04-09-2013          0.0               0                0
# 4   5  05-09-2013          0.0            4999                0

# %%
Room_Temp=DataSet
Room_Temp.rename(columns={'Date': 'ds'}, inplace=True)
Room_Temp.rename(columns={'Room Amount': 'y'}, inplace=True)
Room_Temp.head()
# Out:
#    Sr          ds    y  Dine In Amount  Takeaway Amount
# 0   1  01-09-2013  0.0           53722                0
# 1   2  02-09-2013  0.0           39137                0
# 2   3  03-09-2013  0.0             597                0
# 3   4  04-09-2013  0.0               0                0
# 4   5  05-09-2013  0.0            4999                0

# %%
Data_Room = Room_Temp[['ds', 'y']]
Data_Room.head()
# Out:
#            ds    y
# 0  01-09-2013  0.0
# 1  02-09-2013  0.0
# 2  03-09-2013  0.0
# 3  04-09-2013  0.0
# 4  05-09-2013  0.0

# %%
Room_m = Prophet()
Room_m.fit(Data_Room)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
Room_future = Room_m.make_future_dataframe(periods=365)
Room_future.tail()
# Out:
#              ds
# 3362 2022-12-07
# 3363 2022-12-08
# 3364 2022-12-09
# 3365 2022-12-10
# 3366 2022-12-11

# %%
Room_forecast = Room_m.predict(Room_future)
Room_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds          yhat    yhat_lower    yhat_upper
# 3362 2022-12-07  38369.836515  -2456.480210  73897.529311
# 3363 2022-12-08  43790.665283   5191.262921  77269.177795
# 3364 2022-12-09  43131.695803   5167.913058  80935.573286
# 3365 2022-12-10  46729.449188   7954.952930  84247.151371
# 3366 2022-12-11  48513.014915  10436.327343  85464.372690

# %%
plot_plotly(Room_m,Room_forecast)

# %%
plot_components_plotly(Room_m,Room_forecast)
