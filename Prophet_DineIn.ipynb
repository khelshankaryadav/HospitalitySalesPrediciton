# %%
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
DataSet = pd.read_csv('Dataset.csv')
DataSet.head()
# Out:
#    Sr        Date  Room Amount  Dine In Amount  Takeaway Amount
# 0   1  01-09-2013          0.0           53722                0
# 1   2  02-09-2013          0.0           39137                0
# 2   3  03-09-2013          0.0             597                0
# 3   4  04-09-2013          0.0               0                0
# 4   5  05-09-2013          0.0            4999                0

# %%
DineInAmount_Temp = DataSet
DineInAmount_Temp.rename(columns={'Date': 'ds'}, inplace=True)
DineInAmount_Temp.rename(columns={'Dine In Amount': 'y'}, inplace=True)
DineInAmount_Temp.head()
# Out:
#    Sr          ds  Room Amount      y  Takeaway Amount
# 0   1  01-09-2013          0.0  53722                0
# 1   2  02-09-2013          0.0  39137                0
# 2   3  03-09-2013          0.0    597                0
# 3   4  04-09-2013          0.0      0                0
# 4   5  05-09-2013          0.0   4999                0

# %%
Data_DineInAmount = DineInAmount_Temp[['ds', 'y']]
Data_DineInAmount.head()
# Out:
#            ds      y
# 0  01-09-2013  53722
# 1  02-09-2013  39137
# 2  03-09-2013    597
# 3  04-09-2013      0
# 4  05-09-2013   4999

# %%
DineInAmount_m = Prophet()
DineInAmount_m.fit(Data_DineInAmount)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
DineInAmount_future = DineInAmount_m.make_future_dataframe(periods=365)
DineInAmount_future.tail()
# Out:
#              ds
# 3362 2022-12-07
# 3363 2022-12-08
# 3364 2022-12-09
# 3365 2022-12-10
# 3366 2022-12-11

# %%
DineInAmount_forecast = DineInAmount_m.predict(DineInAmount_future)
DineInAmount_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds         yhat    yhat_lower    yhat_upper
# 3362 2022-12-07  2042.715230 -26198.563341  32036.016191
# 3363 2022-12-08  2041.967496 -26876.441983  28909.686953
# 3364 2022-12-09  3272.976530 -23669.414233  32368.630516
# 3365 2022-12-10  5378.841408 -24306.605825  32035.232832
# 3366 2022-12-11  6651.871309 -22857.979728  33313.232541

# %%
plot_plotly(DineInAmount_m, DineInAmount_forecast)

# %%
plot_components_plotly(DineInAmount_m, DineInAmount_forecast)
